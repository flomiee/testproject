# %%
import math
import numpy as np
import numpy as np
def calculate_sin(x):
    return np.sin(x)

# %%
def calculate_cos(x):
    return np.cos(x)

# %%
x_values = np.linspace(0,2*np.pi, 1000)
sin_values = (x_values)
cos_values = (x_values)
print(f"x (first 5): {x_values[:5]}")
print(f"sin(x) (first 5): {sin_values[:5]}")
print(f"cos(x) (first 5): {cos_values[:5]}")
# Out:
# x (first 5): [0.         0.00628947 0.01257895 0.01886842 0.0251579 ]
# sin(x) (first 5): [0.         0.00628947 0.01257895 0.01886842 0.0251579 ]
# cos(x) (first 5): [0.         0.00628947 0.01257895 0.01886842 0.0251579 ]
